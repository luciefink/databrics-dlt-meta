# %%
# %sql

-- Create schema for dlt-meta project
CREATE SCHEMA IF NOT EXISTS lucie_finkova.dlt_meta_lukas;

-- Create volume for storing data files
CREATE VOLUME IF NOT EXISTS lucie_finkova.dlt_meta_lukas.dlt_meta_data;

-- Create volume for configuration files
CREATE VOLUME IF NOT EXISTS lucie_finkova.dlt_meta_lukas.dlt_meta_conf;

-- Create volume for ddl files
CREATE VOLUME IF NOT EXISTS lucie_finkova.dlt_meta_lukas.dlt_meta_ddl;
